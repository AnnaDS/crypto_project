# %% [markdown]
# ### Crypto data collection

# %%
## Use LUNA to get data
import urllib.request
import json
api_key='9wg27ze73mwope7e8p97c'
url=f'https://api.lunarcrush.com/v2?data=assets&key={api_key}&symbol=BTC&interval=day&data_points=365'
response=urllib.request.urlopen(url).read()
json_data=json.loads(response)

# %%
type(json_data)
# Out:
# dict

# %% [markdown]
# ### Crypto coin overview

# %%
json_data['data'][0].items()#get('id')
overal_stat_keys=['id','name',',symbol','price','price_btc','market_cap','percent_change_24h','percent_change_7d',
             'percent_change_30d','volume_24h','max_supply']
overview=pd.DataFrame()
for k, v in json_data['data'][0].items():
    if k in overal_stat_keys:
        overview=overview.append(pd.DataFrame([v],index=[k]))
overview.transpose()
# Out:
#   id     name    price  ... percent_change_30d   volume_24h max_supply
# 0  1  Bitcoin  31757.8  ...               0.09  2.97605e+10   21000000
#
# [1 rows x 10 columns]

# %% [markdown]
# ### Social response and current information

# %%
additional_summary=pd.DataFrame()
for k, v in json_data['data'][0].items():
    if (k not in overal_stat_keys) and k!='timeSeries':
        #print(k,v)
        additional_summary=additional_summary.append(pd.DataFrame([v], index=[k]))

additional_summary.transpose()
# Out:
#   symbol social_dominance_calc_24h_previous  ... tags    close
# 0    BTC                                  0  ...       31757.8
#
# [1 rows x 84 columns]

# %%
import pandas as pd
BTC_history=pd.DataFrame()
for k in (json_data['data'][0]['timeSeries']):
    BTC_history=BTC_history.append(pd.DataFrame([k]))

# %%
import datetime
BTC_history['date']=BTC_history['time'].apply(lambda x: datetime.datetime.utcfromtimestamp(x))
BTC_history.index=pd.DatetimeIndex(BTC_history['date'])
BTC_history.drop(columns=['asset_id', 'time', 'date'], inplace=True)

# %%
# %matplotlib inline
BTC_history[['open', 'close',  'high']].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
# calculate the correlation matrix
corr = BTC_history.corr()

#Get strong positive correlations
pos_corr=corr[corr['high']>0.75][corr[corr['high']>0.75].index.values]

#Get strong negative correlations
neg_corr=corr[corr['high']<(-0.0)][corr[corr['high']<(-0.0)].index.values]

# plot the heatmap
sns.heatmap(pos_corr, 
        xticklabels=pos_corr.columns,
        yticklabels=pos_corr.columns)
plt.title('Positive correlations')
plt.show()

sns.heatmap(neg_corr, 
        xticklabels=neg_corr.columns,
        yticklabels=neg_corr.columns)
plt.title('Negative correlations')
plt.show()

# %%
import numpy as np
BTC_history[pos_corr.columns].apply(np.log).plot(figsize=[15,8])
# Out:
# <AxesSubplot:xlabel='date'>

# %%
type(corr)
# Out:
# pandas.core.frame.DataFrame

# %%
corr
# Out:
#                              open  ...  percent_change_24h
# open                     1.000000  ...           -0.089322
# close                    0.996805  ...           -0.017863
# high                     0.998530  ...           -0.050659
# low                      0.997236  ...           -0.042947
# volume                   0.794622  ...           -0.085798
# market_cap               0.999106  ...           -0.078936
# url_shares               0.616237  ...           -0.015820
# unique_url_shares        0.487104  ...            0.045964
# reddit_posts             0.777203  ...            0.021735
# reddit_posts_score       0.689861  ...            0.094254
# reddit_comments          0.826809  ...           -0.034506
# reddit_comments_score    0.780037  ...            0.020562
# tweets                   0.615783  ...           -0.017051
# tweet_spam               0.689407  ...           -0.130583
# tweet_followers          0.593733  ...            0.018049
# tweet_quotes             0.377536  ...            0.016172
# tweet_retweets           0.494312  ...            0.017720
# tweet_replies            0.470895  ...           -0.046200
# tweet_favorites          0.528154  ...            0.022677
# tweet_sentiment1         0.493294  ...           -0.068665
# tweet_sentiment2         0.536320  ...           -0.081355
# tweet_sentiment3         0.616150  ...           -0.001478
# tweet_sentiment4         0.595041  ...           -0.002683
# tweet_sentiment5         0.627702  ...           -0.041597
# tweet_sentiment_impact1  0.484550  ...           -0.034004
# tweet_sentiment_impact2  0.443233  ...           -0.140224
# tweet_sentiment_impact3  0.575182  ...           -0.005516
# tweet_sentiment_impact4  0.571372  ...            0.081438
# tweet_sentiment_impact5  0.646417  ...            0.004463
# social_score             0.576035  ...            0.001648
# average_sentiment       -0.022883  ...            0.180793
# sentiment_absolute            NaN  ...                 NaN
# sentiment_relative      -0.116945  ...            0.217394
# news                    -0.324262  ...            0.177644
# price_score              0.017570  ...            0.016840
# social_impact_score     -0.090462  ...           -0.015358
# correlation_rank        -0.155279  ...            0.021695
# galaxy_score            -0.112725  ...            0.018740
# volatility               0.314298  ...            0.022548
# alt_rank                -0.066627  ...           -0.113914
# alt_rank_30d             0.675714  ...           -0.049739
# alt_rank_hour_average    0.182406  ...           -0.171590
# market_cap_rank          0.019229  ...           -0.030374
# percent_change_24h_rank  0.208083  ...           -0.609399
# volume_24h_rank          0.710530  ...           -0.081657
# social_volume_24h_rank   0.196222  ...           -0.016223
# social_score_24h_rank    0.148694  ...            0.004490
# social_contributors      0.456059  ...           -0.092527
# social_volume            0.623383  ...           -0.013944
# price_btc                     NaN  ...                 NaN
# social_volume_global     0.719796  ...           -0.087347
# social_dominance        -0.373690  ...            0.154060
# market_cap_global        0.946418  ...           -0.075766
# market_dominance        -0.330898  ...            0.042920
# percent_change_24h      -0.089322  ...            1.000000
#
# [55 rows x 55 columns]

# %%
## Market aPI test
import urllib.request
url = f'https://api.lunarcrush.com/v2?data=market&key={api_key}'
response=urllib.request.urlopen(url).read()
market_data=json.loads(response)

# %%
market_data['data'][0].keys()
# Out:
# dict_keys(['id', 's', 'n', 'p', 'p_btc', 'v', 'vt', 'pc', 'pch', 'mc', 'gs', 'ss', 'as', 'bl', 'br', 'sp', 'na', 'md', 't', 'r', 'yt', 'sv', 'u', 'c', 'sd', 'd', 'cr', 'acr', 'timeSeries', 'e2', 'nft'])

# %%
market_data['data'][0]['timeSeries']
# Out:
# [{'p': 25.98435834, 'ss': 1093734, 'na': 0, 'ts': 169, 'sv': 927, 'u': 46},
#  {'p': 25.14675719, 'ss': 1816123, 'na': 0, 'ts': 193, 'sv': 783, 'u': 48},
#  {'p': 25.28863789, 'ss': 504559, 'na': 0, 'ts': 108, 'sv': 495, 'u': 28},
#  {'p': 24.41969624, 'ss': 4834086, 'na': 0, 'ts': 103, 'sv': 654, 'u': 27},
#  {'p': 25.170323, 'ss': 1426127, 'na': 0, 'ts': 109, 'sv': 604, 'u': 25},
#  {'p': 24.80114419, 'ss': 946256, 'na': 0, 'ts': 91, 'sv': 660, 'u': 32}]

# %%
(market_data['data'][2])
# Out:
# {'id': 1790,
#  's': 'LUNA',
#  'n': 'Terra',
#  'p': 7.42261552,
#  'p_btc': 0.000230076949785029,
#  'v': 268441214.37,
#  'vt': 0.06874474219919562,
#  'pc': 12.43,
#  'pch': -0.15,
#  'mc': 3107341782,
#  'gs': 66,
#  'ss': 7266883,
#  'as': 3.6,
#  'bl': 2073,
#  'br': 368,
#  'sp': 712,
#  'na': 0,
#  'md': 0,
#  't': 2771,
#  'r': 76,
#  'yt': 0,
#  'sv': 2950,
#  'u': 157,
#  'c': 114,
#  'sd': 0.27462658787399374,
#  'd': 0.2157539266126775,
#  'cr': 3.7,
#  'acr': 3,
#  'timeSeries': [{'p': 7.43552477,
#    'ss': 151966,
#    'na': 0,
#    'ts': 36,
#    'sv': 124,
#    'u': 6},
#   {'p': 7.35596904, 'ss': 303705, 'na': 0, 'ts': 48, 'sv': 166, 'u': 14},
#   {'p': 7.44210528, 'ss': 268763, 'na': 0, 'ts': 36, 'sv': 168, 'u': 7},
#   {'p': 7.4150833, 'ss': 244445, 'na': 0, 'ts': 15, 'sv': 148, 'u': 5},
#   {'p': 7.51392852, 'ss': 447162, 'na': 0, 'ts': 21, 'sv': 152, 'u': 6},
#   {'p': 7.42207038, 'ss': 362137, 'na': 0, 'ts': 36, 'sv': 127, 'u': 7}],
#  'df': 1}

# %%
## Meta info for cryptos
import urllib.request
url = f'https://api.lunarcrush.com/v2?data=meta&key={api_key}'
response=urllib.request.urlopen(url).read()
global_data=json.loads(response)
crypto_meta=pd.DataFrame(global_data.get('data'))

# %%
print(f'Number of crypto currencies in market is {crypto_meta.shape[0]}')
crypto_meta.head()
# Out:
# Number of crypto currencies in market is 2749
#    id          name symbol
# 0   1       Bitcoin    BTC
# 1   2      Ethereum    ETH
# 2   3           XRP    XRP
# 3   4      Litecoin    LTC
# 4   5  Bitcoin Cash    BCH

# %%
## Exchanges info for cryptos
import urllib.request
url = f'https://api.lunarcrush.com/v2?data=exchanges&key={api_key}'
response=urllib.request.urlopen(url).read()
exchange_data=json.loads(response)
exchange_df=pd.DataFrame(exchange_data['data']['exchanges'])

# %%
print(f'Number of crypto exchanges in market is {exchange_df.shape[0]}')
exchange_df.head()
# Out:
# Number of crypto exchanges in market is 454
#     id          name  ... 1d_trades_percent  30d_trades_percent
# 0   32       Binance  ...         56.228608           56.580964
# 1  167           FTX  ...          6.987708            6.349570
# 2  121  Coinbase Pro  ...         11.935378           10.347724
# 3  359          OKEx  ...          0.000000            0.000000
# 4  208  Huobi Global  ...          0.000000            0.000000
#
# [5 rows x 15 columns]

# %%
## Crypto social aspect
url = f'https://api.lunarcrush.com/v2?data=feeds&key={api_key}&limit=100'
response=urllib.request.urlopen(url).read()
feeds_data=json.loads(response)
feeds_df=pd.DataFrame(feeds_data['data'])
feeds_df['date']=feeds_df['time'].apply(lambda x: datetime.datetime.utcfromtimestamp(x))
feeds_df.sort_values('date').tail()
# Out:
#       lunar_id  asset_id symbol  ... publisher  shares                date
# 26  2638081482         1    BTC  ...       NaN     NaN 2021-07-20 17:45:07
# 24  2650487254         1    BTC  ...       NaN     NaN 2021-07-21 18:12:36
# 35  2651069810         1    BTC  ...       NaN     NaN 2021-07-21 19:06:09
# 39  2651291592         1    BTC  ...       NaN     NaN 2021-07-21 19:26:16
# 27  2663218414         1    BTC  ...       NaN     NaN 2021-07-22 14:05:50
#
# [5 rows x 25 columns]

# %%
print('Coins')
feeds_df.name.unique()
feeds_df[feeds_df.name=='Cream Finance']#['body'].values
# Out:
# Coins
#       lunar_id  asset_id symbol  ... publisher  shares                date
# 31  2629724368      2900  CREAM  ...       NaN     NaN 2021-07-19 15:50:04
#
# [1 rows x 25 columns]

# %%
## Crypto social aspect. Influencers per crypto
crypto='ADA'
url = f'https://api.lunarcrush.com/v2?data=influencers&key={api_key}&symbol={crypto}&days=7&num_days=1&limit=100'
response=urllib.request.urlopen(url).read()
influence_data=json.loads(response)
influence_df=pd.DataFrame(influence_data['data'])
influence_df['date']=feeds_df['time'].apply(lambda x: datetime.datetime.utcfromtimestamp(x))
influence_df.sort_values('date').tail()
# Out:
#      medium           identifier  ...  influencer_rank  date
# 95  twitter  1378769020523012096  ...             None   NaT
# 96  twitter  1266782411309842432  ...             None   NaT
# 97  twitter   944519099400499200  ...             None   NaT
# 98  twitter   921195939502723074  ...             None   NaT
# 99  twitter  1378446486904610816  ...             None   NaT
#
# [5 rows x 17 columns]
