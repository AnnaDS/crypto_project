# %%
#Data with Messari
api_key='c8c030f8-48d7-43e5-96ff-19bf03c0bc45'

# %%
from six.moves import urllib
import json
url = "https://data.messari.io/api/v1/assets"
assets_data=json.loads(urllib.request.urlopen(url).read())

# %%
len(assets_data['data'])#[0]#.keys()
# Out:
# 20

# %%
for ass in assets_data['data']:
    print(ass['symbol'])
# Out:
# BTC
# ETH
# USDT
# BNB
# ADA
# USDC
# DOGE
# XRP
# DOT
# BUSD
# UNI
# BCH
# LTC
# SOL
# LINK
# WBTC
# MATIC
# DAI
# ETC
# CUBE

# %%
from six.moves import urllib
url = "https://data.messari.io/api/v1/assets/btc"
meta_data=json.loads(urllib.request.urlopen(url).read())
meta_data
# Out:
# {'status': {'elapsed': 2, 'timestamp': '2021-07-22T23:09:59.405706921Z'},
#  'data': {'id': '1e31218a-e44e-4285-820c-8282ee222035',
#   'symbol': 'BTC',
#   'name': 'Bitcoin',
#   'slug': 'bitcoin',
#   'contract_addresses': [],
#   '_internal_temp_agora_id': '9793eae6-f374-46b4-8764-c2d224429791'}}

# %%
url = "https://data.messari.io/api/v1/assets/btc/metrics"
asset_metric=json.loads(urllib.request.urlopen(url).read())
asset_metric
# Out:
# {'status': {'elapsed': 2, 'timestamp': '2021-07-22T23:11:17.202515246Z'},
#  'data': {'id': '1e31218a-e44e-4285-820c-8282ee222035',
#   'symbol': 'BTC',
#   'name': 'Bitcoin',
#   'slug': 'bitcoin',
#   'contract_addresses': [],
#   '_internal_temp_agora_id': '9793eae6-f374-46b4-8764-c2d224429791',
#   'market_data': {'price_usd': 32250.737655213463,
#    'price_btc': 1,
#    'price_eth': 16.047691806417962,
#    'volume_last_24_hours': 19808027641.61061,
#    'real_volume_last_24_hours': 3571807573.8943334,
#    'volume_last_24_hours_overstatement_multiple': 5.545659230464637,
#    'percent_change_usd_last_1_hour': 0.09536448136646745,
#    'percent_change_btc_last_1_hour': 0,
#    'percent_change_eth_last_1_hour': 0.33177716937266,
#    'percent_change_usd_last_24_hours': 0.3167521705633938,
#    'percent_change_btc_last_24_hours': 0,
#    'percent_change_eth_last_24_hours': -0.357451192999653,
#    'ohlcv_last_1_hour': {'open': 32198.513990587413,
#     'high': 32273.669336735315,
#     'low': 32062.688623026344,
#     'close': 32249.2292675698,
#     'volume': 102788308.81479932},
#    'ohlcv_last_24_hour': {'open': 31845.568037702044,
#     'high': 32603.155962665922,
#     'low': 31727.99007871257,
#     'close': 32250.73765521346,
#     'volume': 3905763306.754971},
#    'last_trade_at': '2021-07-22T23:11:15.312Z'},
#   'marketcap': {'rank': 1,
#    'marketcap_dominance_percent': 45.50984469523573,
#    'current_marketcap_usd': 604827020849.8568,
#    'y_2050_marketcap_usd': 676236720268.2014,
#    'y_plus10_marketcap_usd': 664704283583.5422,
#    'liquid_marketcap_usd': 604973578736.3243,
#    'volume_turnover_last_24_hours_percent': 0.5895658748268516,
#    'realized_marketcap_usd': 362668443375.7352,
#    'outstanding_marketcap_usd': 602653902984.2953},
#   'supply': {'y_2050': 20986335.65,
#    'y_plus10': 20628437.92,
#    'liquid': 18774754.76,
#    'circulating': 18770206.48140853,
#    'y_2050_issued_percent': 89.46180540098244,
#    'annual_inflation_percent': 1.7904584869261835,
#    'stock_to_flow': 55.85161606939998,
#    'y_plus10_issued_percent': 91.01394314397994,
#    'supply_revived_90d': 18762775.04292917},
#   'blockchain_stats_24_hours': {'count_of_active_addresses': 815589,
#    'transaction_volume': 14215480348.952253,
#    'adjusted_transaction_volume': 6161966960.957484,
#    'adjusted_nvt': 97.802196409481,
#    'median_tx_value': 155.95410489088084,
#    'median_tx_fee': 0.30674272650670326,
#    'count_of_tx': 237007,
#    'count_of_payments': 697662,
#    'new_issuance': 29108439.360910974,
#    'average_difficulty': 13672594272814.14,
#    'kilobytes_added': 203139.207,
#    'count_of_blocks_added': 145},
#   'market_data_liquidity': {'clearing_prices_to_sell': None,
#    'marketcap': None,
#    'asset_bid_depth': None,
#    'usd_bid_depth': None,
#    'updated_at': '0001-01-01T00:00:00Z'},
#   'all_time_high': {'price': 64654.1484598988,
#    'at': '2021-04-14T06:00:00Z',
#    'days_since': 99,
#    'percent_down': 50.20623616455416,
#    'breakeven_multiple': 2.008283614198586},
#   'cycle_low': {'price': 29249.24325054555,
#    'at': '2021-06-22T13:00:00Z',
#    'percent_up': 10.066895468620643,
#    'days_since': 30},
#   'token_sale_stats': {'sale_proceeds_usd': None,
#    'sale_start_date': None,
#    'sale_end_date': None,
#    'roi_since_sale_usd_percent': None,
#    'roi_since_sale_btc_percent': None,
#    'roi_since_sale_eth_percent': None},
#   'staking_stats': {'staking_yield_percent': None,
#    'staking_type': None,
#    'staking_minimum': None,
#    'tokens_staked': None,
#    'tokens_staked_percent': None,
#    'real_staking_yield_percent': None},
#   'mining_stats': {'mining_algo': 'SHA-256',
#    'network_hash_rate': '103023 PH/s',
#    'available_on_nicehash_percent': 0.25762194943845185,
#    '1_hour_attack_cost': None,
#    '24_hours_attack_cost': None,
#    'attack_appeal': None,
#    'hash_rate': 98551910.00153977,
#    'hash_rate_30d_average': 95343953.48609212,
#    'mining_revenue_per_hash_usd': 3.474583e-06,
#    'mining_revenue_per_hash_native_units': 1.08e-10,
#    'mining_revenue_per_hash_per_second_usd': 0.300203998524,
#    'mining_revenue_per_hash_per_second_native_units': 9.346426e-06,
#    'mining_revenue_from_fees_percent_last_24_hours': 1.6130713404,
#    'mining_revenue_native': 921.10813128,
#    'mining_revenue_usd': 29612483.7816645,
#    'mining_revenue_total': 29920588333.255733,
#    'average_difficulty': 13672594272814.14},
#   'developer_activity': {'stars': 55741,
#    'watchers': 3830,
#    'commits_last_3_months': 470,
#    'commits_last_1_year': 2864,
#    'lines_added_last_3_months': 12433,
#    'lines_added_last_1_year': 154270,
#    'lines_deleted_last_3_months': 9334,
#    'lines_deleted_last_1_year': 110504},
#   'roi_data': {'percent_change_last_1_week': 0.9773942513896773,
#    'percent_change_last_1_month': -1.0187741836735118,
#    'percent_change_last_3_months': -37.086132251425425,
#    'percent_change_last_1_year': 238.1402548324609,
#    'percent_change_btc_last_1_week': 0,
#    'percent_change_btc_last_1_month': 0,
#    'percent_change_btc_last_3_months': 0,
#    'percent_change_btc_last_1_year': 0,
#    'percent_change_eth_last_1_week': -3.3354925797465698,
#    'percent_change_eth_last_1_month': -7.188958062961303,
#    'percent_change_eth_last_3_months': -25.645156242989437,
#    'percent_change_eth_last_1_year': -55.495705790384164,
#    'percent_change_month_to_date': -3.9556243515971734,
#    'percent_change_quarter_to_date': -3.9556243515971734,
#    'percent_change_year_to_date': 9.518913202442898},
#   'roi_by_year': {'2020_usd_percent': 301.45619677746635,
#    '2019_usd_percent': 83.83497240467483,
#    '2018_usd_percent': -72.35180629416075,
#    '2017_usd_percent': 1293.9968257264447,
#    '2016_usd_percent': 122.23036668622065,
#    '2015_usd_percent': 36.81278481514266,
#    '2014_usd_percent': -57.34726933565019,
#    '2013_usd_percent': 5394.285470792129,
#    '2012_usd_percent': 156.47080487351116,
#    '2011_usd_percent': 1474.0066666666667},
#   'risk_metrics': {'sharpe_ratios': {'last_30_days': 0.1982384309145477,
#     'last_90_days': -1.371558351296366,
#     'last_1_year': 1.8515956719965534,
#     'last_3_years': 0.6832300759304892},
#    'volatility_stats': {'volatility_last_30_days': 0.6834510941358506,
#     'volatility_last_90_days': 0.9542958861549686,
#     'volatility_last_1_year': 0.7890620840215175,
#     'volatility_last_3_years': 0.7617859007284066}},
#   'misc_data': {'private_market_price_usd': None,
#    'vladimir_club_cost': 112521942.62648736,
#    'btc_current_normalized_supply_price_usd': 53624.02235180804,
#    'btc_y2050_normalized_supply_price_usd': 53624.02235180803,
#    'asset_created_at': '2009-01-03',
#    'asset_age_days': 4582,
#    'categories': ['Payments'],
#    'sectors': ['Currencies'],
#    'tags': None},
#   'lend_rates': {'bitfinex': 3.0961,
#    'blockfi': 3.2,
#    'celsius': 4.41,
#    'coinlist': 2.92,
#    'cryptocom': 6,
#    'poloniex': 0.584},
#   'borrow_rates': {'coinlist': 3.65},
#   'loan_data': {'originated_last_24_hours_usd': None,
#    'outstanding_debt_usd': None,
#    'repaid_last_24_hours_usd': None,
#    'collateralized_last_24_hours_usd': None,
#    'collateral_liquidated_last_24_hours_usd': None},
#   'reddit': {'active_user_count': 5685, 'subscribers': 3206534},
#   'on_chain_data': {'addresses_count': 38019533,
#    'active_addresses': 815589,
#    'active_addresses_received_count': 575723,
#    'active_addresses_sent_count': 524912,
#    'addresses_balance_greater_0_001_native_units_count': 18640096,
#    'addresses_balance_greater_0_01_native_units_count': 9014540,
#    'addresses_balance_greater_0_1_native_units_count': 3179007,
#    'addresses_balance_greater_1_usd_count': 31988204,
#    'addresses_balance_greater_1_native_units_count': 799662,
#    'addresses_balance_greater_10_usd_count': 23257217,
#    'addresses_balance_greater_10_native_units_count': 146943,
#    'addresses_balance_greater_100_usd_count': 13682855,
#    'addresses_balance_greater_100_native_units_count': 16056,
#    'addresses_balance_greater_100k_usd_count': 310143,
#    'addresses_balance_greater_100k_native_units_count': 3,
#    'addresses_balance_greater_10k_usd_count': 1640141,
#    'addresses_balance_greater_10k_native_units_count': 87,
#    'addresses_balance_greater_10m_usd_count': 6076,
#    'addresses_balance_greater_1k_usd_count': 5410056,
#    'addresses_balance_greater_1k_native_units_count': 2156,
#    'addresses_balance_greater_1m_usd_count': 75086,
#    'addresses_balance_greater_1m_native_units_count': 0,
#    'average_block_gas_limit': None,
#    'block_height': 692076,
#    'average_block_interval': 583.61111111,
#    'blocks_added_last_24_hours': 145,
#    'block_size_bytes_total': 158326183,
#    'block_size_bytes_average': 1091904.7103448275,
#    'uncle_blocks_count_last_24_hours': None,
#    'uncle_rewards_last_24_hours_usd': None,
#    'uncle_rewards_last_24_hours_native_units': None,
#    'mining_revenue_from_uncle_blocks_percent_last_24_hours': None,
#    'block_weight': 465916741,
#    'average_block_weight': 3213218.90344828,
#    'total_fees_last_24_hours': 14.85813128,
#    'total_fees_last_24_hours_usd': 477238.08373002434,
#    'hash_rate': 98551910.00153977,
#    'issuance_last_24_hours_native_units': 906.25,
#    'issuance_rate_daily': 0.0048300425,
#    'issuance_total_usd': 29108439.360910974,
#    'issuance_total_native_units': 906.25,
#    'new_issuance': 29108439.360910974,
#    'issuance_rate': 1.7629655125,
#    'realized_marketcap_usd': 362668443375.7352,
#    'adjusted_nvt': 97.802196409481,
#    'adjusted_nvt_90d_moving_average': 57.066874729259965,
#    'adjusted_rvt': 58.855953898101,
#    'adjusted_rvt_90d_moving_average': 34.34202371193823,
#    'txn_count_last_24_hours': 237007,
#    'txn_contracts_calls_count_last_24_hours': None,
#    'txn_contracts_calls_success_count_last_24_hours': None,
#    'txn_contracts_creation_count_last_24_hours': None,
#    'txn_contracts_destruction_count_last_24_hours': None,
#    'txn_contracts_count_last_24_hours': None,
#    'txn_erc20_count_last_24_hours': None,
#    'txn_erc721_count_last_24_hours': None,
#    'txn_per_second_count': 2.743136574074,
#    'txn_token_count_last_24_hours': None,
#    'average_fee_usd': 2.0135813114874583,
#    'average_fee_native_units': 6.269e-05,
#    'median_fee_usd': 0.30674272650670326,
#    'median_fee_native_units': 9.55e-06,
#    'average_txn_gas_used': None,
#    'txn_gas_limit_last_24_hours': None,
#    'average_txn_gas_limit': None,
#    'txn_gas_used_last_24_hours': None,
#    'transfer_count_last_24_hours': 697662,
#    'transfer_erc_20_count_last_24_hours': None,
#    'transfer_erc721_count_last_24_hours': None,
#    'txn_volume_last_24_hours_usd': 14215480348.952253,
#    'adjusted_txn_volume_last_24_hours_usd': 6161966960.957484,
#    'adjusted_txn_volume_last_24_hours_native_units': 191844.10710341,
#    'txn_volume_last_24_hours_native_units': 442578.83105674,
#    'average_transfer_value_usd': 20375.884524256715,
#    'average_transfer_value_native_units': 0.634374283044,
#    'median_transfer_value_usd': 155.95410489088084,
#    'median_transfer_value_native_units': 0.00485541,
#    'average_utxo_age': 1051.29156985,
#    'value_weighted_average_utxo_age': 1158.35947605,
#    'median_utxo_age': 808,
#    'utxo_count_last_24_hours': 74863272,
#    'utxo_in_loss_count': 16458004,
#    'utxo_in_profit_count': 58405268},
#   'exchange_flows': {'flow_in_exchange_native_units': 23195.53349002,
#    'flow_in_exchange_usd': 745032584.8697675,
#    'flow_in_exchange_native_units_inclusive': 32023.98960604,
#    'flow_in_exchange_usd_inclusive': 1028599569.1496372,
#    'flow_out_exchange_native_units': 30870.2956983,
#    'flow_out_exchange_usd': 991543316.2894968,
#    'flow_out_exchange_native_units_inclusive': 39698.75181432,
#    'flow_out_exchange_usd_inclusive': 1275110300.5693665,
#    'flow_in_binance_usd': 357455645.3707427,
#    'flow_in_binance_native_units': 11128.87484625,
#    'flow_in_bitfinex_usd': 61032639.11542604,
#    'flow_in_bitfinex_native_units': 1900.16470868,
#    'flow_in_bitmex_usd': 11102975.438095804,
#    'flow_in_bitmex_native_units': 345.67540245,
#    'flow_in_bitstamp_usd': 69857867.52822764,
#    'flow_in_bitstamp_native_units': 2174.92568607,
#    'flow_in_bittrex_usd': 172524831.02321932,
#    'flow_in_bittrex_native_units': 5371.3160701,
#    'flow_in_gemini_usd': 44345235.888084374,
#    'flow_in_gemini_native_units': 1380.62606261,
#    'flow_in_huobi_usd': 114272375.96873763,
#    'flow_in_huobi_native_units': 3557.70845141,
#    'flow_in_kraken_usd': 125345171.38536541,
#    'flow_in_kraken_native_units': 3902.44424167,
#    'flow_in_poloniex_usd': 6168530.271691295,
#    'flow_in_poloniex_native_units': 192.04844648,
#    'flow_net_binance_usd': -77305895.58482043,
#    'flow_net_binance_native_units': -2406.80948247,
#    'flow_net_bitfinex_usd': 56610778.6832028,
#    'flow_net_bitfinex_native_units': 1762.49635185,
#    'flow_net_bitmex_usd': -525659.5086384511,
#    'flow_net_bitmex_native_units': -16.36566371,
#    'flow_net_bitstamp_usd': 1699084.6035831994,
#    'flow_net_bitstamp_native_units': 52.89859078,
#    'flow_net_bittrex_usd': 939346.124873053,
#    'flow_net_bittrex_native_units': 29.24521013,
#    'flow_net_gemini_usd': -27746117.65026523,
#    'flow_net_gemini_native_units': -863.83604455,
#    'flow_net_huobi_usd': -172273914.6018517,
#    'flow_net_huobi_native_units': -5363.50414298,
#    'flow_net_kraken_usd': 7335842.995865968,
#    'flow_net_kraken_native_units': 228.39107355,
#    'flow_net_poloniex_usd': 2920654.6020953516,
#    'flow_net_poloniex_native_units': 90.93044118,
#    'flow_out_binance_usd': 436683161.0880056,
#    'flow_out_binance_native_units': 13595.51124776,
#    'flow_out_bitfinex_usd': 4421860.432223238,
#    'flow_out_bitfinex_native_units': 137.66835683,
#    'flow_out_bitmex_usd': 11628634.946734255,
#    'flow_out_bitmex_native_units': 362.04106616,
#    'flow_out_bitstamp_usd': 75172985.47482459,
#    'flow_out_bitstamp_native_units': 2340.40434947,
#    'flow_out_bittrex_usd': 173002128.12842545,
#    'flow_out_bittrex_native_units': 5386.17603893,
#    'flow_out_gemini_usd': 72626969.13345562,
#    'flow_out_gemini_native_units': 2261.13773951,
#    'flow_out_huobi_usd': 287451409.1288793,
#    'flow_out_huobi_native_units': 8949.39217775,
#    'flow_out_kraken_usd': 134124917.11697134,
#    'flow_out_kraken_native_units': 4175.78918025,
#    'flow_out_poloniex_usd': 3248093.616887657,
#    'flow_out_poloniex_native_units': 101.12479078,
#    'supply_exchange_native_units': 1655062.66698319,
#    'supply_exchange_usd': 53208211630.45385,
#    'supply_binance_usd': 18055010971.6846,
#    'supply_binance_native_units': 562117.17468652,
#    'supply_bitfinex_usd': 6449988695.303081,
#    'supply_bitfinex_native_units': 200811.25554838,
#    'supply_bitmex_usd': 3545564759.3238454,
#    'supply_bitmex_native_units': 110386.13315189,
#    'supply_bitstamp_usd': 1417093617.8806658,
#    'supply_bitstamp_native_units': 44119.2011458,
#    'supply_bittrex_usd': 3855388808.2918777,
#    'supply_bittrex_native_units': 120032.06575913,
#    'supply_gemini_usd': 8469285441.592624,
#    'supply_gemini_native_units': 263679.19750965,
#    'supply_huobi_usd': 4093510973.2038183,
#    'supply_huobi_native_units': 127445.66183949,
#    'supply_kraken_usd': 5181249620.182489,
#    'supply_kraken_native_units': 161310.86280757,
#    'supply_poloniex_usd': 904545413.9540765,
#    'supply_poloniex_native_units': 28161.7393235},
#   'miner_flows': {'supply_1hop_miners_usd': 89703312330.6456,
#    'supply_1hop_miners_native_units': 2792785.48024168,
#    'supply_miners_usd': 57636605648.46315,
#    'supply_miners_native_units': 1794434.02036395},
#   'supply_activity': {'supply_active_10y': 16475654.27405628,
#    'supply_active_180d': 5855529.19558309,
#    'supply_active_1d': 242498.81974843,
#    'supply_active_1y': 8592333.06975725,
#    'supply_active_1y_percent': 45.7945748968,
#    'supply_active_2y': 10229256.04134914,
#    'supply_active_30d': 1591511.80329335,
#    'supply_active_3y': 12158220.76784165,
#    'supply_active_4y': 13946125.88561697,
#    'supply_active_5y': 14576253.0786605,
#    'supply_active_7d': 666860.96176671,
#    'supply_active_90d': 3475017.70686964,
#    'supply_active_ever': 16990576.12505381,
#    'outstanding': 10799.85571764,
#    'supply_revived_1y': 1666.56673471,
#    'supply_revived_2y': 1038.49402247,
#    'supply_revived_30d': 24446.45789357,
#    'supply_revived_3y': 799.65493346,
#    'supply_revived_4y': 327.17475768,
#    'supply_revived_5y': 149.11354639,
#    'supply_revived_7d': 39775.90649303,
#    'supply_revived_90d': 16946.42148004},
#   'supply_distribution': {'supply_in_addresses_balance_greater_0_001_native_units': 18756194.36542673,
#    'supply_in_addresses_balance_greater_0_01_native_units': 18719517.09684957,
#    'supply_in_addresses_balance_greater_0_1_native_units': 18529541.17635589,
#    'supply_in_addresses_balance_greater_1_usd': 18760085.370421,
#    'supply_in_addresses_balance_greater_10_usd': 18758992.57451213,
#    'supply_in_addresses_balance_greater_100_usd': 18747246.59290751,
#    'supply_in_addresses_balance_greater_100k_usd': 17007802.35218145,
#    'supply_in_addresses_balance_greater_100k_native_units': 594279.6749824,
#    'supply_in_addresses_balance_greater_100_native_units': 11850899.10679033,
#    'supply_in_addresses_balance_greater_10k_usd': 18265024.17241265,
#    'supply_in_addresses_balance_greater_10k_native_units': 2716423.60102127,
#    'supply_in_addresses_balance_greater_10m_usd': 10233792.8998912,
#    'supply_in_addresses_balance_greater_10_native_units': 16111023.21653904,
#    'supply_in_addresses_balance_greater_1k_usd': 18658515.0425056,
#    'supply_in_addresses_balance_greater_1k_native_units': 7917282.74579792,
#    'supply_in_addresses_balance_greater_1m_usd': 14924786.432793,
#    'supply_in_addresses_balance_greater_1m_native_units': 0,
#    'supply_in_addresses_balance_greater_1_native_units': 17785512.69997708,
#    'supply_in_contracts_usd': None,
#    'supply_in_contracts_native_units': None,
#    'supply_shielded': None,
#    'supply_in_top_100_addresses': 2844225.41929148,
#    'supply_in_top_10_percent_addresses': 18583133.97826849,
#    'supply_in_top_1_percent_addresses': 17200569.11727216,
#    'supply_in_utxo_in_loss': 5534025.56559261,
#    'supply_in_utxo_in_profit': 13228749.47733656},
#   'alert_messages': None}}

# %%
url = "https://data.messari.io/api/v1/assets/btc/metrics/market-data"
asset_metrics=json.loads(urllib.request.urlopen(url).read())

asset_metrics
# Out:
# {'status': {'elapsed': 4, 'timestamp': '2021-07-22T23:14:18.503039942Z'},
#  'data': {'id': '1e31218a-e44e-4285-820c-8282ee222035',
#   'symbol': 'BTC',
#   'name': 'Bitcoin',
#   'slug': 'bitcoin',
#   'contract_addresses': [],
#   '_internal_temp_agora_id': '9793eae6-f374-46b4-8764-c2d224429791',
#   'market_data': {'price_usd': 32251.45572004338,
#    'price_btc': 1,
#    'price_eth': 16.049124805079355,
#    'volume_last_24_hours': 19808027641.61061,
#    'real_volume_last_24_hours': 3575517633.0230565,
#    'volume_last_24_hours_overstatement_multiple': 5.539904896193496,
#    'percent_change_usd_last_1_hour': 0.11612779614008154,
#    'percent_change_btc_last_1_hour': 0,
#    'percent_change_eth_last_1_hour': 0.26440524542828187,
#    'percent_change_usd_last_24_hours': 0.31898572975684225,
#    'percent_change_btc_last_24_hours': 0,
#    'percent_change_eth_last_24_hours': -0.34855348728716457,
#    'ohlcv_last_1_hour': {'open': 32234.34482410848,
#     'high': 32276.200069825703,
#     'low': 32062.688623026344,
#     'close': 32249.195361438065,
#     'volume': 101756945.71735094},
#    'ohlcv_last_24_hour': {'open': 31845.568037702044,
#     'high': 32603.155962665922,
#     'low': 31727.99007871257,
#     'close': 32251.455720043385,
#     'volume': 3908580260.84429},
#    'last_trade_at': '2021-07-22T23:14:17.058Z'}}}

# %%
# IMPORT LIBRARIES
import json
import csv
from six.moves import urllib


# CREATING LIST OF TICKERS
assets_url = f"https://data.messari.io/api/v1/assets"
assets_bytes = urllib.request.urlopen(assets_url).read()
#assets_json = assets_bytes.decode('utf8').replace("'", '"')
assets_dict = json.loads(assets_bytes)

ticker_list = []

for asset in assets_dict["data"]:
    if (asset["symbol"] == "mkr") or (asset["symbol"] == "vet") or (asset["symbol"] == "ark") or (asset["symbol"] == "nxt") or (asset["symbol"] == "icn") or (asset["symbol"] == "dcn") or (asset["symbol"] == "gxs"):
        pass
    else:
        ticker_list.append(asset["symbol"])



# STORE METRICS & PROFILES FOR EACH TICKER
assets_details_list = []

for ticker in ticker_list:
    # ASSETS METRICS
    metrics_url = (f"https://data.messari.io/api/v1/assets/{ticker}/metrics")
    metrics_bytes = urllib.request.urlopen(metrics_url).read()
    metrics_json = metrics_bytes.decode('utf8')
    metrics_dict = json.loads(metrics_json)

    metrics_data = metrics_dict["data"]
    del metrics_data["symbol"]
    del metrics_data["market_data"]
    #del metrics_data["blockchain_stats_last_24_hours"]

    # PROFILE METRICS
    profile_url = (f"https://data.messari.io/api/v1/assets/{ticker}/profile")
    profile_bytes = urllib.request.urlopen(profile_url).read()
    profile_json = profile_bytes.decode('utf8')
    profile_dict = json.loads(profile_json)

    profile_full_data = profile_dict["data"]
    profile_data = {}
    profile_data["token_distribution"] = profile_full_data["token_distribution"]
    del profile_data["token_distribution"]["description"]

    # COMBINING METRICS & PROFILE
    full_data = {}
    full_data["symbol"] = ticker
    full_data["metrics"] = metrics_data
    full_data["profile"] = profile_data
    assets_details_list.append(full_data)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-21-53ff50403f97> in <module>
#      27     # ASSETS METRICS
#      28     metrics_url = (f"https://data.messari.io/api/v1/assets/{ticker}/metrics")
# ---> 29     metrics_bytes = urllib.request.urlopen(metrics_url).read()
#      30     metrics_json = metrics_bytes.decode('utf8')
#      31     metrics_dict = json.loads(metrics_json)
#
# /opt/anaconda3/envs/python3_env/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /opt/anaconda3/envs/python3_env/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# /opt/anaconda3/envs/python3_env/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# /opt/anaconda3/envs/python3_env/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# /opt/anaconda3/envs/python3_env/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# /opt/anaconda3/envs/python3_env/lib/python3.7/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 429: Too Many Requests

# %%
ticker_list
# Out:
# ['BTC',
#  'ETH',
#  'USDT',
#  'BNB',
#  'ADA',
#  'USDC',
#  'DOGE',
#  'XRP',
#  'DOT',
#  'BUSD',
#  'UNI',
#  'BCH',
#  'LTC',
#  'SOL',
#  'LINK',
#  'WBTC',
#  'MATIC',
#  'DAI',
#  'ETC',
#  'THETA']
