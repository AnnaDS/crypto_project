# %% [markdown]
# ## Try XGBOOST as Forecats model for Crypto prediction

# %%
import pandas as pd
import xgboost
from matplotlib import pyplot as plt
#from sklearn import

# %%
data=pd.read_csv('data/DOT_histical_data.csv')
print(f'Dataset has {data.shape[0]} features and {data.shape[0]} historical values')
print(f'Data is collected from {str(data.date.min())} to {str(data.date.max())}')
data.info()
# Out:
# Dataset has 345 features and 345 historical values
# Data is collected from 2020-08-13 to 2021-07-23
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 345 entries, 0 to 344
# Data columns (total 59 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   date                     345 non-null    object
#  1   open                     345 non-null    float64
#  2   close                    345 non-null    float64
#  3   high                     345 non-null    float64
#  4   low                      345 non-null    float64
#  5   volume                   345 non-null    float64
#  6   market_cap               335 non-null    float64
#  7   url_shares               335 non-null    float64
#  8   unique_url_shares        335 non-null    float64
#  9   reddit_posts             316 non-null    float64
#  10  reddit_posts_score       316 non-null    float64
#  11  reddit_comments          287 non-null    float64
#  12  reddit_comments_score    287 non-null    float64
#  13  tweets                   335 non-null    float64
#  14  tweet_spam               335 non-null    float64
#  15  tweet_followers          335 non-null    float64
#  16  tweet_quotes             335 non-null    float64
#  17  tweet_retweets           335 non-null    float64
#  18  tweet_replies            335 non-null    float64
#  19  tweet_favorites          335 non-null    float64
#  20  tweet_sentiment1         335 non-null    float64
#  21  tweet_sentiment2         335 non-null    float64
#  22  tweet_sentiment3         335 non-null    float64
#  23  tweet_sentiment4         335 non-null    float64
#  24  tweet_sentiment5         335 non-null    float64
#  25  tweet_sentiment_impact1  335 non-null    float64
#  26  tweet_sentiment_impact2  335 non-null    float64
#  27  tweet_sentiment_impact3  335 non-null    float64
#  28  tweet_sentiment_impact4  335 non-null    float64
#  29  tweet_sentiment_impact5  335 non-null    float64
#  30  social_score             335 non-null    float64
#  31  average_sentiment        335 non-null    float64
#  32  sentiment_absolute       335 non-null    float64
#  33  sentiment_relative       335 non-null    float64
#  34  search_average           0 non-null      float64
#  35  news                     266 non-null    float64
#  36  price_score              335 non-null    float64
#  37  social_impact_score      335 non-null    float64
#  38  correlation_rank         335 non-null    float64
#  39  galaxy_score             335 non-null    float64
#  40  volatility               335 non-null    float64
#  41  alt_rank                 335 non-null    float64
#  42  alt_rank_30d             335 non-null    float64
#  43  alt_rank_hour_average    335 non-null    float64
#  44  market_cap_rank          335 non-null    float64
#  45  percent_change_24h_rank  335 non-null    float64
#  46  volume_24h_rank          335 non-null    float64
#  47  social_volume_24h_rank   335 non-null    float64
#  48  social_score_24h_rank    335 non-null    float64
#  49  medium                   71 non-null     float64
#  50  youtube                  34 non-null     float64
#  51  social_contributors      344 non-null    float64
#  52  price_btc                345 non-null    float64
#  53  percent_change_24h       344 non-null    float64
#  54  social_volume            335 non-null    float64
#  55  social_volume_global     335 non-null    float64
#  56  social_dominance         335 non-null    float64
#  57  market_cap_global        331 non-null    float64
#  58  market_dominance         331 non-null    float64
# dtypes: float64(58), object(1)
# memory usage: 159.1+ KB

# %%
#Remove the columns that contains nan values only
nan_stat= (data.isnull().sum())
for col_name, val in nan_stat.items():
    if val>data.shape[0]*0.75:
        data.drop(columns=[col_name], inplace=True)

# %% [markdown]
# ### Transform dataset for supervised learning

# %%
# transform a time series dataset into a supervised learning dataset
def series_to_supervised(data, target, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols = list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, -1, -1):
        #cols.append(pd.DataFrame(df.shift(i).values, columns=[col+'-'+str(i) for col in df.columns]))
        df_shift=df.shift(i)
        df_shift.columns=[col+'-'+str(i) for col in df_shift.columns]
        cols.append(df_shift)#df.shift(i))

    # forecast sequence (t, t+1, ... t+n)
    for i in range(1, (n_out+1)):
        target_shift=target.shift(-i)
        cols.append(target.shift(-i))
    #cols.append(target.shift(-n_out))

    # put it all together
    agg = pd.concat(cols, axis=1)

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg#.values

#Select features
#Select features excluding date
set_columns=data.columns[1:]
#select target feature
target_column='close'
#get features dataset
df=data[set_columns].fillna(0)
#get target vector
target=data[target_column]

#Run rtransformation to dataset for supervised learning
#n_in - number of historical lags to include in forecast
#n_out - number of lags predicted in future
#for example we want to predict 7 days in the future using history of last two weeks
#n_out=7, n_in=14
n_in=24
n_out=1
#Transform dataframe for supervised learning
res=series_to_supervised(df, target, n_in=n_in, n_out=n_out, dropnan=True)

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error
from xgboost import XGBRegressor
#build xgboost prediction model
# split a univariate dataset into train/test sets
def train_test_split(data, n_test):
    return data[:-n_test, :], data[-n_test:, :]
#Use the data with lag to predict the value in number of N_pred values in n_out steps
N_pred=30
train, test=train_test_split(res.values, N_pred)

testX, testy = test[:, :-n_out-1], test[:, -1]
trainX, trainy = train[:, :-n_out-1], train[:, -1]

# fit model
model = XGBRegressor(objective='reg:squarederror', n_estimators=1000)
model.fit(trainX, trainy)
# make a prediction for test dataset
yhat = model.predict(np.asarray(testX))

#Plot the results
index_pred=df.index.values[-N_pred:]
yhat_df=pd.Series(yhat, index=index_pred)
yhat_df.plot(label='prediction')
#pd.Series(testy, index=index_pred).plot(label='expected')

df.loc[index_pred]['close'].plot(label='original')
plt.legend()
print(f'RMSE is {mean_absolute_error(testy, yhat)}')
# Out:
# RMSE is 2.112186732919922

# %%
#Find the most important features
#using the probability of influence
def features_importance_ratio(model, ratio=0.95):
    valuable_features=[i for i,v in enumerate(model.feature_importances_) if v > np.quantile(model.feature_importances_, ratio)]
    return [x for x in res.columns[valuable_features]]
#using the top N
import operator
def features_importance_top_N(model, topN=10):
    dict_features={}
    for i,v in enumerate(model.feature_importances_):
        dict_features[i]=v
    sorted_d = dict( sorted(dict_features.items(), key=operator.itemgetter(1),reverse=True))
    valuable_features=list(sorted_d.keys())[:topN]
    return [x for x in res.columns[valuable_features]]
#Get the most valuable features
features=features_importance_ratio(model, ratio=0.95)

# %%
print('List of selected features based on the selected thrshhold of importance')
features
# Out:
# List of selected features based on the selected thrshhold of importance
# ['url_shares-24',
#  'tweet_spam-24',
#  'tweet_quotes-24',
#  'tweet_sentiment1-24',
#  'social_volume_24h_rank-24',
#  'social_contributors-24',
#  'price_btc-24',
#  'market_cap-23',
#  'tweet_followers-23',
#  'tweet_sentiment1-23',
#  'tweet_sentiment_impact2-23',
#  'close-22',
#  'price_btc-22',
#  'market_dominance-22',
#  'url_shares-20',
#  'tweet_sentiment5-20',
#  'tweet_sentiment_impact3-20',
#  'unique_url_shares-19',
#  'tweet_sentiment4-19',
#  'volume-18',
#  'reddit_posts-18',
#  'alt_rank_hour_average-18',
#  'market_cap_global-18',
#  'market_dominance-18',
#  'tweet_sentiment2-17',
#  'tweet_sentiment3-17',
#  'tweet_sentiment_impact2-17',
#  'market_cap_global-17',
#  'open-16',
#  'close-15',
#  'tweets-15',
#  'alt_rank-15',
#  'market_dominance-15',
#  'open-14',
#  'market_cap_global-14',
#  'low-13',
#  'tweet_sentiment4-13',
#  'market_cap_global-12',
#  'tweet_sentiment5-11',
#  'alt_rank_30d-11',
#  'market_cap_global-11',
#  'volume-9',
#  'alt_rank_30d-9',
#  'market_dominance-9',
#  'url_shares-8',
#  'tweet_quotes-8',
#  'tweet_sentiment1-8',
#  'medium-7',
#  'close-5',
#  'tweet_sentiment1-5',
#  'open-4',
#  'high-4',
#  'volume-4',
#  'tweet_sentiment1-4',
#  'price_score-4',
#  'volatility-4',
#  'alt_rank_30d-4',
#  'high-3',
#  'low-3',
#  'close-2',
#  'galaxy_score-2',
#  'close-1',
#  'low-1',
#  'volume-1',
#  'reddit_comments_score-1',
#  'tweet_quotes-1',
#  'tweet_sentiment_impact1-1',
#  'volume_24h_rank-1',
#  'close-0',
#  'high-0',
#  'low-0',
#  'market_cap-0',
#  'tweet_followers-0']

# %%
## Train and test model with selected features only
trainX_feat, testX_feat=train_test_split(res[features].values, N_pred) 
# fit model
modelf = XGBRegressor(objective='reg:squarederror', n_estimators=1000)
modelf.fit(trainX_feat, trainy)
# make a prediction for test dataset
yhat = modelf.predict(np.asarray(testX_feat))

#Plot the results
index_pred=df.index.values[-N_pred:]
yhat_df=pd.Series(yhat, index=index_pred)
yhat_df.plot(label='prediction')
#pd.Series(testy, index=index_pred).plot(label='expected')

df.loc[index_pred]['close'].plot(label='original')
plt.legend()
print(f'RMSE is {mean_absolute_error(testy, yhat)}')
# Out:
# RMSE is 2.088108781653402

# %%
#try SelectFromModel sklearn approach for feature selection
from sklearn.feature_selection import SelectFromModel
selector = SelectFromModel(model, prefit=True)
select_X_train = selector.transform(trainX)
# train model
selection_model = XGBRegressor(objective='reg:squarederror', n_estimators=1000)
selection_model.fit(select_X_train, trainy)
# eval model
select_X_test = selector.transform(testX)
y_pred = selection_model.predict(select_X_test)
predictions = [(value) for value in y_pred]
pred_df=pd.Series(predictions, index=index_pred)
pred_df.plot(label='prediction')
#pd.Series(testy, index=index_pred).plot(label='expected')

df.loc[index_pred]['close'].plot(label='original')
plt.legend()
print(f'RMSE is {mean_absolute_error(testy, predictions)}')
# Out:
# RMSE is 1.4869207501012374

# %%
## Check if the error can be decreased using different threshholds of feature importance
from sklearn.metrics import accuracy_score
thresholds = np.sort(model.feature_importances_)
thresholds
for thresh in np.unique(thresholds)[-50:]:
    #print(thresh)
    # select features using threshold
    selection = SelectFromModel(model, threshold=thresh, prefit=True)
    select_X_train = selection.transform(trainX)
    # train model
    selection_model = XGBRegressor(objective='reg:squarederror', n_estimators=1000)
    selection_model.fit(select_X_train, trainy)
    # eval model
    select_X_test = selection.transform(testX)
    y_pred = selection_model.predict(select_X_test)
    predictions = [(value) for value in y_pred]
    mae = mean_absolute_error(testy, predictions)
    print("Thresh=%.5f, n=%d, MAE: %.3f" % (thresh, select_X_train.shape[1], mae))
# Out:
# Thresh=0.00013, n=50, MAE: 2.030
# Thresh=0.00013, n=49, MAE: 2.098
# Thresh=0.00013, n=48, MAE: 2.043
# Thresh=0.00014, n=47, MAE: 2.149
# Thresh=0.00014, n=46, MAE: 2.289
# Thresh=0.00015, n=45, MAE: 2.045
# Thresh=0.00016, n=44, MAE: 2.225
# Thresh=0.00017, n=43, MAE: 2.028
# Thresh=0.00019, n=42, MAE: 2.045
# Thresh=0.00019, n=41, MAE: 2.064
# Thresh=0.00020, n=40, MAE: 2.070
# Thresh=0.00020, n=39, MAE: 1.998
# Thresh=0.00022, n=38, MAE: 2.240
# Thresh=0.00023, n=37, MAE: 2.334
# Thresh=0.00024, n=36, MAE: 2.266
# Thresh=0.00024, n=35, MAE: 2.251
# Thresh=0.00026, n=34, MAE: 2.323
# Thresh=0.00027, n=33, MAE: 2.404
# Thresh=0.00031, n=32, MAE: 2.037
# Thresh=0.00032, n=31, MAE: 2.135
# Thresh=0.00040, n=30, MAE: 2.209
# Thresh=0.00041, n=29, MAE: 2.228
# Thresh=0.00042, n=28, MAE: 2.088
# Thresh=0.00045, n=27, MAE: 2.034
# Thresh=0.00046, n=26, MAE: 2.151
# Thresh=0.00051, n=25, MAE: 2.284
# Thresh=0.00051, n=24, MAE: 1.491
# Thresh=0.00064, n=23, MAE: 1.448
# Thresh=0.00074, n=22, MAE: 1.487
# Thresh=0.00081, n=21, MAE: 1.460
# Thresh=0.00091, n=20, MAE: 1.431
# Thresh=0.00151, n=19, MAE: 1.506
# Thresh=0.00151, n=18, MAE: 1.481
# Thresh=0.00185, n=17, MAE: 1.475
# Thresh=0.00201, n=16, MAE: 1.938
# Thresh=0.00210, n=15, MAE: 1.692
# Thresh=0.00214, n=14, MAE: 2.093
# Thresh=0.00219, n=13, MAE: 1.797
# Thresh=0.00431, n=12, MAE: 1.852
# Thresh=0.00479, n=11, MAE: 1.593
# Thresh=0.00743, n=10, MAE: 2.271
# Thresh=0.01758, n=9, MAE: 1.923
# Thresh=0.01845, n=8, MAE: 2.240
# Thresh=0.04072, n=7, MAE: 2.431
# Thresh=0.04292, n=6, MAE: 2.527
# Thresh=0.04543, n=5, MAE: 1.603
# Thresh=0.05844, n=4, MAE: 1.775
# Thresh=0.09638, n=3, MAE: 1.725
# Thresh=0.10665, n=2, MAE: 1.652
# Thresh=0.52956, n=1, MAE: 1.801

# %%
features=features_importance_top_N(model, topN=20)
print('List of selected features based on the selected thrshhold of importance')
print(features)
## Train and test model with selected features only
trainX_feat, testX_feat=train_test_split(res[features].values, N_pred) 
# fit model
modelf = XGBRegressor(objective='reg:squarederror', n_estimators=1000)
modelf.fit(trainX_feat, trainy)
# make a prediction for test dataset
yhat = modelf.predict(np.asarray(testX_feat))

#Plot the results
index_pred=df.index.values[-N_pred:]
yhat_df=pd.Series(yhat, index=index_pred)
yhat_df.plot(label='prediction')
#pd.Series(testy, index=index_pred).plot(label='expected')

df.loc[index_pred]['close'].plot(label='original')
plt.legend()
print(f'RMSE is {mean_absolute_error(testy, yhat)}')
# Out:
# List of selected features based on the selected thrshhold of importance
# ['high-0', 'market_cap_global-17', 'low-1', 'close-0', 'market_cap_global-18', 'low-3', 'close-15', 'close-2', 'open-14', 'market_cap_global-11', 'low-0', 'close-5', 'market_cap_global-12', 'open-4', 'alt_rank_30d-11', 'market_cap_global-14', 'volume-1', 'market_cap-23', 'tweet_sentiment4-13', 'close-1']
# RMSE is 1.4382271341367192

# %% [markdown]
# ### Continue to explore predicting each day and adding it value for one step forward forecast

# %%
# transform a time series dataset into a supervised learning dataset
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols = list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
    # put it all together
    agg = pd.concat(cols, axis=1)
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg.values

# split a univariate dataset into train/test sets
def train_test_split(data, n_test):
    return data[:-n_test, :], data[-n_test:, :]
 
# fit an xgboost model and make a one step prediction
def xgboost_forecast(train, testX):
    # transform list into array
    train = np.asarray(train)
    # split into input and output columns
    trainX, trainy = train[:, :-1], train[:, -1]
    # fit model
    model = XGBRegressor(objective='reg:squarederror', n_estimators=1000)
    model.fit(trainX, trainy)
    # make a one-step prediction
    yhat = model.predict(np.asarray([testX]))
    return yhat[0]
 
# walk-forward validation for univariate data
def walk_forward_validation(data, n_test):
    predictions = list()
    # split dataset
    train, test = train_test_split(data, n_test)
    # seed history with training dataset
    history = [x for x in train]
    # step over each time-step in the test set
    for i in range(len(test)):
        # split test row into input and output columns
        testX, testy = test[i, :-1], test[i, -1]
        # fit model on history and make a prediction
        yhat = xgboost_forecast(history, testX)
        # store forecast in list of predictions
        predictions.append(yhat)
        # add actual observation to history for the next loop
        history.append(test[i])
        # summarize progress
        print('>expected=%.1f, predicted=%.1f' % (testy, yhat))
    # estimate prediction error
    error = mean_absolute_error(test[:, -1], predictions)
    return error, test[:, -1], predictions
 
    
sup_data=series_to_supervised(data[['close']], n_in=6)
# evaluate
mae, y, yhat = walk_forward_validation(sup_data, 12)
# Out:
# /opt/anaconda3/envs/python3_env/lib/python3.7/site-packages/xgboost/core.py:444: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# >expected=14.9, predicted=16.7
# >expected=14.2, predicted=16.6
# >expected=13.8, predicted=15.6
# >expected=13.1, predicted=15.0
# >expected=12.1, predicted=13.9
# >expected=12.3, predicted=12.5
# >expected=12.7, predicted=12.4
# >expected=11.5, predicted=12.7
# >expected=11.0, predicted=11.7
# >expected=12.4, predicted=11.5
# >expected=13.2, predicted=12.0
# >expected=12.5, predicted=12.5

# %%
data.tail()
# Out:
#            date       open      close       high        low        volume  \
# 340  2021-07-19  12.659186  11.495162  12.756441  11.391805  9.353971e+08
# 341  2021-07-20  11.480408  10.982207  11.559666  10.403210  1.032411e+09
# 342  2021-07-21  10.989894  12.362557  12.858393  10.742165  1.404588e+09
# 343  2021-07-22  12.375220  13.182885  13.384020  11.857660  1.245650e+09
# 344  2021-07-23  13.171055  12.543549  13.529863  12.391981  7.787467e+08
#
#        market_cap  url_shares  unique_url_shares  reddit_posts  ...  medium  \
# 340  1.256179e+10       332.0              198.0          14.0  ...     NaN
# 341  1.149260e+10       488.0              268.0          11.0  ...     NaN
# 342  1.085993e+10       250.0              185.0           3.0  ...     NaN
# 343  1.231380e+10       274.0              204.0          17.0  ...     NaN
# 344  1.332177e+10       239.0              190.0           9.0  ...     NaN
#
#      youtube  social_contributors  price_btc  percent_change_24h  \
# 340      NaN               2774.0   0.000372           -9.279229
# 341      1.0               5699.0   0.000368           -4.462353
# 342      NaN               2591.0   0.000384           12.568964
# 343      NaN               4203.0   0.000407            6.635583
# 344      NaN               2331.0   0.000386           -3.230000
#
#      social_volume  social_volume_global  social_dominance  market_cap_global  \
# 340         3738.0             1058660.0          0.353088       1.378915e+12
# 341         6713.0             1085896.0          0.618199       1.319836e+12
# 342         3121.0             1236175.0          0.252472       1.433972e+12
# 343         4538.0             1109318.0          0.409080       1.446023e+12
# 344         2409.0             1063838.0          0.226444       1.435831e+12
#
#      market_dominance
# 340          0.910991
# 341          0.870760
# 342          0.757332
# 343          0.851563
# 344          0.927809
#
# [5 rows x 59 columns]

# %%
# walk-forward validation for univariate data
def walk_forward_validation(data, n_test):
    predictions = list()
    # split dataset
    train, test = train_test_split(data, n_test)
    # seed history with training dataset
    history = [x for x in train]
    # step over each time-step in the test set
    for i in range(len(test)):
        # split test row into input and output columns
        testX, testy = test[i, :-1], test[i, -1]
        # fit model on history and make a prediction
        yhat = xgboost_forecast(history, testX)
        # store forecast in list of predictions
        predictions.append(yhat)
        # add actual observation to history for the next loop
        history.append(test[i])
        # summarize progress
        print('>expected=%.1f, predicted=%.1f' % (testy, yhat))
    # estimate prediction error
    error = mean_absolute_error(test[:, -1], predictions)
    return error, test[:, 1], predictions


# split a univariate dataset into train/test sets
def train_test_split(data, n_test):
	return data[:-n_test, :], data[-n_test:, :]
